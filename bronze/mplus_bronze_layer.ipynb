# %% [markdown]
# ## Bronze Layer Ingestion
# Load raw Raider.io Mythic+ run JSON files into the Bronze table.
# No transformations or cleaning are applied in this step.

# %%
from pyspark.sql.functions import input_file_name, current_timestamp

bronze_path = "/Volumes/workspace/raiderio-api/raiderio-api"

df_bronze = spark.read.option("multiline", "true").json(bronze_path)

display(df_bronze)

# %%
df_bronze.write \
    .format("delta") \
    .mode("append") \
    .saveAsTable("workspace.bronze_mythic_plus_runs.mythic_runs_bronze")

# %%
df_bronze = spark.table("workspace.bronze_mythic_plus_runs.mythic_runs_bronze")

df_bronze.show()
